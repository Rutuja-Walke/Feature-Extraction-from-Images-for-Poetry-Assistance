# %%
import numpy as np
from keras.preprocessing.image import image
from keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt

# %% [markdown]
# ## ResNet50

# %%
from tensorflow.keras.applications import ResNet50

# %%
modelResNet50 = ResNet50(weights='imagenet')
# Out:
# ...
# 102981632/102967424 [==============================] - 1s 0us/step

# %%
def display_predict(path, model):
  model = model
  img = image.load_img(path, target_size = (224, 224))
  plt.imshow(img)
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis=0)
  img = preprocess_input(img)
  preds = model.predict(img)
  print('Predicted:', decode_predictions(preds, top=1)[0])

# %%
display_predict("/content/alps.jfif", modelResNet50)
# Out:
# Predicted: [('n09193705', 'alp', 0.98265266)]

# %%
display_predict("/content/sunset_beach.jfif", modelResNet50)
# Out:
# Predicted: [('n09428293', 'seashore', 0.75431067)]

# %%
display_predict("/content/sunset island palm.jfif", modelResNet50)
# Out:
# Predicted: [('n03347037', 'fire_screen', 0.345372)]

# %%
display_predict("/content/sunflower.jpg", modelResNet50)
# Out:
# Predicted: [('n11939491', 'daisy', 0.9274164)]

# %%
display_predict("/content/temple.jpg", modelResNet50)
# Out:
# Predicted: [('n03877845', 'palace', 0.90741295), ('n04346328', 'stupa', 0.041483004), ('n03781244', 'monastery', 0.011564368), ('n03903868', 'pedestal', 0.009765033), ('n04486054', 'triumphal_arch', 0.0056754346)]

# %% [markdown]
# **ResNet50V2**

# %%
from tensorflow.keras.applications import ResNet50V2
import tensorflow
from tensorflow.keras.applications.resnet_v2 import decode_predictions

# %%
def display_predict(path, model):
  model = model
  img = image.load_img(path, target_size = (224, 224))
  plt.imshow(img)
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis=0)
  img = preprocess_input(img)
  preds = model.predict(img)
  print('Predicted:', tensorflow.keras.applications.resnet_v2.decode_predictions(preds, top=5)[0])

# %%
modelResNet50V2 = ResNet50V2(weights='imagenet')
# Out:
# ...
# 102883328/102869336 [==============================] - 4s 0us/step

# %%
display_predict("/content/sunset_beach_23.jfif", modelResNet50V2)
# Out:
# Predicted: [('n02089973', 'English_foxhound', 1.0), ('n02356798', 'fox_squirrel', 1.8154099e-27), ('n03690938', 'lotion', 2.6540983e-37), ('n15075141', 'toilet_tissue', 0.0), ('n02319095', 'sea_urchin', 0.0)]

# %%
display_predict("/content/alps.jfif", modelResNet50V2)
# Out:
# Predicted: [('n02356798', 'fox_squirrel', 1.0), ('n04254777', 'sock', 1.0126741e-11), ('n01688243', 'frilled_lizard', 2.2568588e-12), ('n02999410', 'chain', 7.568121e-15), ('n02085782', 'Japanese_spaniel', 5.6682606e-15)]

# %%
display_predict("/content/sunflower.jpg", modelResNet50V2)
# Out:
# Predicted: [('n07615774', 'ice_lolly', 1.0), ('n02089973', 'English_foxhound', 1.043698e-23), ('n15075141', 'toilet_tissue', 0.0), ('n02317335', 'starfish', 0.0), ('n02389026', 'sorrel', 0.0)]

# %% [markdown]
# ## ResNet101

# %%
from tensorflow.keras.applications import ResNet101

# %%
modelResNet101 = ResNet101(weights='imagenet')

# %%
display_predict("/content/alps.jfif", modelResNet101)
# Out:
# Predicted: [('n09193705', 'alp', 0.98956376), ('n09468604', 'valley', 0.008392073), ('n03792972', 'mountain_tent', 0.0008337242), ('n09246464', 'cliff', 0.00032652006), ('n04065272', 'recreational_vehicle', 0.0002000423)]

# %%
display_predict("/content/sunflower.jpg", modelResNet101)
# Out:
# Predicted: [('n11939491', 'daisy', 0.9080992), ('n02206856', 'bee', 0.05715941), ('n04522168', 'vase', 0.027267316), ('n03991062', 'pot', 0.0009849133), ('n03930313', 'picket_fence', 0.00087165745)]

# %%
display_predict("/content/sunset island palm.jfif", modelResNet101)
# Out:
# Predicted: [('n09472597', 'volcano', 0.24964634), ('n03347037', 'fire_screen', 0.12536103), ('n03956157', 'planetarium', 0.08992275), ('n09428293', 'seashore', 0.07335397), ('n02782093', 'balloon', 0.05953078)]

# %%
display_predict("/content/sunset_beach.jfif", modelResNet101)
# Out:
# Predicted: [('n09428293', 'seashore', 0.9014189)]

# %% [markdown]
# ## ResNet152 V2

# %%
import tensorflow
from tensorflow.keras.applications import ResNet152V2
from tensorflow.keras.applications.resnet_v2 import decode_predictions

# %%
def display_predict(path, model):
  model = model
  img = image.load_img(path, target_size = (224, 224))
  plt.imshow(img)
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis=0)
  img = preprocess_input(img)
  preds = model.predict(img)
  print('Predicted:', tensorflow.keras.applications.resnet_v2.decode_predictions(preds, top=5)[0])

# %%
modelResNet152V2 = ResNet152V2(weights='imagenet')

# %%
display_predict("/content/sunflower.jpg", modelResNet152V2)
# Out:
# Predicted: [('n03602883', 'joystick', 1.0), ('n02841315', 'binoculars', 4.4198638e-26), ('n15075141', 'toilet_tissue', 0.0), ('n02342885', 'hamster', 0.0), ('n02321529', 'sea_cucumber', 0.0)]

# %%
display_predict("/content/alps.jfif", modelResNet152V2)
# Out:
# Predicted: [('n02841315', 'binoculars', 1.0)]

# %%
display_predict("/content/lion.jpg", modelResNet152V2)
# Out:
# Predicted: [('n02841315', 'binoculars', 1.0), ('n15075141', 'toilet_tissue', 0.0), ('n02281787', 'lycaenid', 0.0), ('n02389026', 'sorrel', 0.0), ('n02364673', 'guinea_pig', 0.0)]

# %% [markdown]
# # Xception

# %%
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications.xception import decode_predictions
import tensorflow as tf

# %%
modelX = Xception(weights='imagenet')
# Out:
# ...
# 91897856/91884032 [==============================] - 1s 0us/step

# %%
IMAGE_PATH='/content/crowd.jfif'
img=tf.keras.preprocessing.image.load_img(IMAGE_PATH,target_size=(299,299))
img=tf.keras.preprocessing.image.img_to_array(img)
#view the image
plt.imshow(img/255.)

# %%
import requests
#fetching labels from Imagenet  
response=requests.get('https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json')
imgnet_map=response.json()
imgnet_map={v[1]:k for k, v in imgnet_map.items()}
#make model predictions
img=tf.keras.applications.xception.preprocess_input(img)
predictions=modelX.predict(np.array([img]))
decode_predictions(predictions,top=5)
# Out:
# ...
# 49152/35363 [=========================================] - 0s 0us/step
# [[('n03729826', 'matchstick', 0.070982344),
#   ('n01930112', 'nematode', 0.045285888),
#   ('n03196217', 'digital_clock', 0.044125393),
#   ('n04286575', 'spotlight', 0.018615061),
#   ('n03590841', "jack-o'-lantern", 0.018550107)]]

# %%
IMAGE_PATH='/content/temple.jpg'
img=tf.keras.preprocessing.image.load_img(IMAGE_PATH,target_size=(299,299))
img=tf.keras.preprocessing.image.img_to_array(img)
#view the image
plt.imshow(img/255.)

# %%
#make model predictions
img=tf.keras.applications.xception.preprocess_input(img)
predictions=model.predict(np.array([img]))
decode_predictions(predictions,top=5)
# Out:
# [[('n03877845', 'palace', 0.49119577),
#   ('n04346328', 'stupa', 0.26766127),
#   ('n03220513', 'dome', 0.05896241),
#   ('n04486054', 'triumphal_arch', 0.013635689),
#   ('n03837869', 'obelisk', 0.010125278)]]

# %% [markdown]
# ## VGG16

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input,decode_predictions
import numpy as np

# %%
model = VGG16(weights='imagenet')
# Out:
# ...
# 553476096/553467096 [==============================] - 4s 0us/step

# %%
img_path = '/content/sunset_beach.jfif'
#There is an interpolation method to match the source size with the target size
#image loaded in PIL (Python Imaging Library)
img = image.load_img(img_path,color_mode='rgb', target_size=(224, 224))
display(img)
# Converts a PIL Image to 3D Numy Array
x = image.img_to_array(img)
x.shape
# Adding the fouth dimension, for number of images
x = np.expand_dims(x, axis=0)
#mean centering with respect to Image
x = preprocess_input(x)
features = model.predict(x)
p = decode_predictions(features)
p
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F87BA761FD0>
# [[('n09428293', 'seashore', 0.45115304),
#   ('n02814860', 'beacon', 0.19919012),
#   ('n09332890', 'lakeside', 0.11764396),
#   ('n09472597', 'volcano', 0.101796344),
#   ('n09288635', 'geyser', 0.024347086)]]

# %%
img_path = '/content/crowd.jfif'
#There is an interpolation method to match the source size with the target size
#image loaded in PIL (Python Imaging Library)
img = image.load_img(img_path,color_mode='rgb', target_size=(224, 224))
display(img)
# Converts a PIL Image to 3D Numy Array
x = image.img_to_array(img)
x.shape
# Adding the fouth dimension, for number of images
x = np.expand_dims(x, axis=0)
#mean centering with respect to Image
x = preprocess_input(x)
features = model.predict(x)
p = decode_predictions(features)
p
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F6B4924BDD0>
# [[('n04296562', 'stage', 0.8936383),
#   ('n04418357', 'theater_curtain', 0.012355246),
#   ('n03388043', 'fountain', 0.010545098),
#   ('n03028079', 'church', 0.008049293),
#   ('n04081281', 'restaurant', 0.0071776137)]]

# %%
img_path = '/content/sunflower.jpg'
#There is an interpolation method to match the source size with the target size
#image loaded in PIL (Python Imaging Library)
img = image.load_img(img_path,color_mode='rgb', target_size=(224, 224))
display(img)
# Converts a PIL Image to 3D Numy Array
x = image.img_to_array(img)
x.shape
# Adding the fouth dimension, for number of images
x = np.expand_dims(x, axis=0)
#mean centering with respect to Image
x = preprocess_input(x)
features = model.predict(x)
p = decode_predictions(features)
p
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F87BA6F58D0>
# [[('n11939491', 'daisy', 0.8548972),
#   ('n02206856', 'bee', 0.04862663),
#   ('n04522168', 'vase', 0.024441822),
#   ('n02219486', 'ant', 0.006706122),
#   ('n07730033', 'cardoon', 0.005300043)]]

# %%
img_path = '/content/temple.jpg'
#There is an interpolation method to match the source size with the target size
#image loaded in PIL (Python Imaging Library)
img = image.load_img(img_path,color_mode='rgb', target_size=(224, 224))
display(img)
# Converts a PIL Image to 3D Numy Array
x = image.img_to_array(img)
x.shape
# Adding the fouth dimension, for number of images
x = np.expand_dims(x, axis=0)
#mean centering with respect to Image
x = preprocess_input(x)
features = model.predict(x)
p = decode_predictions(features)
p
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F87BA5A5990>
# [[('n03877845', 'palace', 0.62313527),
#   ('n03781244', 'monastery', 0.16319482),
#   ('n04346328', 'stupa', 0.13368274),
#   ('n03788195', 'mosque', 0.019189725),
#   ('n03220513', 'dome', 0.019005068)]]

# %%
img_path = '/content/sunset island palm.jfif'
#There is an interpolation method to match the source size with the target size
#image loaded in PIL (Python Imaging Library)
img = image.load_img(img_path,color_mode='rgb', target_size=(224, 224))
display(img)
# Converts a PIL Image to 3D Numy Array
x = image.img_to_array(img)
x.shape
# Adding the fouth dimension, for number of images
x = np.expand_dims(x, axis=0)
#mean centering with respect to Image
x = preprocess_input(x)
features = model.predict(x)
p = decode_predictions(features)
p
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F87BA55DB50>
# [[('n02948072', 'candle', 0.0614058),
#   ('n02825657', 'bell_cote', 0.05934034),
#   ('n09428293', 'seashore', 0.049454056),
#   ('n03837869', 'obelisk', 0.04086432),
#   ('n03388043', 'fountain', 0.03915577)]]
