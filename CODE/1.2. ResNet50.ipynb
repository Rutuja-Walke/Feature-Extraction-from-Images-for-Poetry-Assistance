# %%
import numpy as np
from keras.preprocessing.image import image
from keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.applications import ResNet50
modelResNet50 = ResNet50(weights='imagenet')
# Out:
# ...
# 102981632/102967424 [==============================] - 1s 0us/step

# %%
def display_predict(path, model):
  model = model
  img = image.load_img(path, target_size = (224, 224))
  plt.imshow(img)
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis=0)
  img = preprocess_input(img)
  preds = model.predict(img)
  X = decode_predictions(preds, top=5)[0]
  print('Top Predicted:')
  for i in X:
    print(i[1] + ": " + str(i[2]))

# %%
display_predict("/content/drive/MyDrive/MajorProject/DATASET/Images/alps.jfif", modelResNet50)
# Out:
# Top Predicted:
# alp: 0.9826528
# valley: 0.009947186
# cliff: 0.0030105996
# mountain_tent: 0.0019553988
# lakeside: 0.00039590368

# %%
display_predict("/content/drive/MyDrive/MajorProject/DATASET/Images/sunset_beach.jfif", modelResNet50)
# Out:
# Top Predicted:
# seashore: 0.7543109
# breakwater: 0.095441855
# beacon: 0.07547243
# lakeside: 0.010774382
# cliff: 0.007405463

# %%
display_predict("/content/drive/MyDrive/MajorProject/DATASET/Images/sunflower.jpg", modelResNet50)
# Out:
# Top Predicted:
# daisy: 0.92741656
# bee: 0.033590835
# vase: 0.0050753765
# picket_fence: 0.003976237
# rapeseed: 0.003898181

# %%
display_predict("/content/drive/MyDrive/MajorProject/DATASET/Images/temple.jpg", modelResNet50)
# Out:
# Top Predicted:
# palace: 0.9074128
# stupa: 0.041482918
# monastery: 0.0115644
# pedestal: 0.009765097
# triumphal_arch: 0.0056754556

# %%
display_predict("/content/drive/MyDrive/MajorProject/DATASET/Images/lion.jpg", modelResNet50)
# Out:
# Top Predicted:
# lion: 0.98998874
# Arabian_camel: 0.003239209
# hyena: 0.0012103751
# llama: 0.00056509103
# baboon: 0.00052262977

# %%
display_predict("/content/drive/MyDrive/MajorProject/DATASET/Images/sunset_beach_23.jfif", modelResNet50)
# Out:
# Top Predicted:
# hyena: 0.38692728
# Arabian_camel: 0.060687557
# warthog: 0.056817833
# wallaby: 0.050055157
# African_elephant: 0.027933225

# %%
display_predict("/content/drive/MyDrive/MajorProject/DATASET/Images/sunset island palm.jfif", modelResNet50)
# Out:
# Top Predicted:
# fire_screen: 0.34537262
# fountain: 0.14694765
# seashore: 0.14602591
# tripod: 0.073560946
# volcano: 0.04639439
